# %%
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload
import pixie_read_st as pxr

# %%
import master_read as m
import efit_plots as e
import os
import sys

# %%
plt.style.use('ggplot')
plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.labelweight'] = 'heavy'
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['figure.titlesize'] = 12
plt.rcParams['text.usetex']=True

# %%
eqdsk_file = "/users/giannis_kx/eqdsks/SN_fr_11_sh.geqdsk"

# %%
filepath = "/lustre/scratch4/turquoise/giannis_kx/pixie3d/iter/int_kink/11/chipar/"

# %%
def eqdsk_info():
    global a
    sys.stdout = open(os.devnull, 'w')
    m.read_geqdsk(eqdsk_file)
    m.struct_hor_ax_det()
    e.gridsNunits()
    e.intersections()
    sys.stdout = sys.__stdout__

# %%
pxr.pixieload(filepath + "pixie3d.h5")
# Out:
# timesteps= 120
# Dictionary of terms:
# Variables: ['Car_variables', 'Cnv_variables', 'Cov_variables', 'Diagnostics', 'Perturbations', 'cells', 'nodes']
# Cartesian: ['Bx', 'By', 'Bz', 'Jx', 'Jy', 'Jz', 'Te', 'Ve_1', 'Ve_2', 'Ve_3', 'Vx', 'Vy', 'Vz', 'rho']
# Contravariant: ['B^1', 'B^2', 'B^3', 'J*P^2', 'J^1', 'J^2', 'J^3', 'JxRho', 'JxTe', 'P^1', 'P^3']
# Covariant: ['B_1', 'B_2', 'B_3', 'J_1', 'J_2', 'J_3', 'T=Te+Ti', 'V_1', 'V_2', 'V_3', 'rho']
# Diagnostic: ['E_1', 'E_2', 'E_3', 'Int. heat src', 'Poloidal flux', 'chi par', 'chi perp', 'diff', 'eta', 'lambda', 'local div(B)', 'local div(J)', 'local div(V)', 'nu', 'pi+pe', 'q factor']
# Perturbations: ['B^1_pert', 'B^2_pert', 'B^3_pert', 'P^1_pert', 'P^2_pert', 'P^3_pert', 'Rho_pert', 'Te_pert']
# Cell: ['X', 'Y', 'Z']
# Node: ['X', 'Y', 'Z']

# %%
pxr.Coordinate_Maps_Interpolations()

# %%
eqdsk_info()

# %%
ap = 2.18095

# %%
reload(pxr)
# Out:
# <module 'pixie_read_st' from '/users/giannis_kx/python_pixie/pixie_read_st.py'>

# %% [markdown]
# ## t=920

# %%
le920_path = "/lustre/scratch4/turquoise/giannis_kx/pixie3d/iter/int_kink/11/ftle-chipar/t-920/"

A920 = np.load(le920_path+"raw_t-920.sav.npz_giri_2.py.npz")

rs920 = A920['rr']
us920 = A920['th']
LE920 = A920['Lyap_exp']

plt.figure(figsize=(8,8))
plt.contourf(rs920,us920,LE920,30,cmap="coolwarm")
plt.colorbar()
plt.show()

x920 = pxr.x_array(rs920,us920)
z920 = pxr.z_array(rs920,us920)

plt.figure(figsize=(20,20))
plt.contourf(x920,z920,np.swapaxes(LE920,0,1),200,vmax = 0.2, cmap="magma")
plt.plot([x/ap for x in m.DS.rbbbs],[y/ap for y in m.DS.zbbbs],"k--")
plt.xlabel('R(m)')
plt.ylabel('Z(m)')
plt.axes().set_aspect("equal")
plt.colorbar()
plt.show()
# Out:
# /usr/projects/hpcsoft/toss3/common/anaconda/5.0.1-python-3.6/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## t=970

# %%
le970_path = "/lustre/scratch4/turquoise/giannis_kx/pixie3d/iter/int_kink/11/ftle-chipar/t-970/"

A970 = np.load(le970_path+"raw_t-970.sav.npz_giri_2.py.npz")

rs970 = A970['rr']
us970 = A970['th']
LE970 = A970['Lyap_exp']

plt.figure(figsize=(8,8))
plt.contourf(rs970,us970,LE970,30,cmap="coolwarm")
plt.colorbar()
plt.show()

x970 = pxr.x_array(rs970,us970)
z970 = pxr.z_array(rs970,us970)

plt.figure(figsize=(20,20))
plt.contourf(x970,z970,np.swapaxes(LE970,0,1),200,vmax = 0.2, cmap="magma")
plt.plot([x/ap for x in m.DS.rbbbs],[y/ap for y in m.DS.zbbbs],"k--")
plt.xlabel('R(m)')
plt.ylabel('Z(m)')
plt.axes().set_aspect("equal")
plt.colorbar()
plt.show()
# Out:
# /usr/projects/hpcsoft/toss3/common/anaconda/5.0.1-python-3.6/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## t=1020

# %%
le1020_path = "/lustre/scratch4/turquoise/giannis_kx/pixie3d/iter/int_kink/11/ftle-chipar/t-1020/"

A1020 = np.load(le1020_path+"raw_t-1020.sav.npz_giri_2.py.npz")

rs1020 = A1020['rr']
us1020 = A1020['th']
LE1020 = A1020['Lyap_exp']

plt.figure(figsize=(8,8))
plt.contourf(rs1020,us1020,LE1020,30,cmap="coolwarm")
plt.colorbar()
plt.show()

x1020 = pxr.x_array(rs1020,us1020)
z1020 = pxr.z_array(rs1020,us1020)

plt.figure(figsize=(20,20))
plt.contourf(x1020,z1020,np.swapaxes(LE1020,0,1),200,vmax = 0.2, cmap="magma")
plt.plot([x/ap for x in m.DS.rbbbs],[y/ap for y in m.DS.zbbbs],"k--")
plt.xlabel('R(m)')
plt.ylabel('Z(m)')
plt.axes().set_aspect("equal")
plt.colorbar()
plt.show()
# Out:
# /usr/projects/hpcsoft/toss3/common/anaconda/5.0.1-python-3.6/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## t=1070

# %%
le1070_path = "/lustre/scratch4/turquoise/giannis_kx/pixie3d/iter/int_kink/11/ftle-chipar/t-1070/"

A1070 = np.load(le1070_path+"raw_t-1070.sav.npz_giri_2.py.npz")

rs1070 = A1070['rr']
us1070 = A1070['th']
LE1070 = A1070['Lyap_exp']

plt.figure(figsize=(8,8))
plt.contourf(rs1070,us1070,LE1070,30,cmap="coolwarm")
plt.colorbar()
plt.show()

x1070 = pxr.x_array(rs1070,us1070)
z1070 = pxr.z_array(rs1070,us1070)

plt.figure(figsize=(20,20))
plt.contourf(x1070,z1070,np.swapaxes(LE1070,0,1),200,vmax = 0.2, cmap="magma")
plt.plot([x/ap for x in m.DS.rbbbs],[y/ap for y in m.DS.zbbbs],"k--")
plt.xlabel('R(m)')
plt.ylabel('Z(m)')
plt.axes().set_aspect("equal")
plt.colorbar()
plt.show()
# Out:
# /usr/projects/hpcsoft/toss3/common/anaconda/5.0.1-python-3.6/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## t=1120

# %%
le1120_path = "/lustre/scratch4/turquoise/giannis_kx/pixie3d/iter/int_kink/11/ftle-chipar/t-1120/"

A1120 = np.load(le1120_path+"raw_t-1120.sav.npz_giri_2.py.npz")

rs1120 = A1120['rr']
us1120 = A1120['th']
LE1120 = A1120['Lyap_exp']

plt.figure(figsize=(8,8))
plt.contourf(rs1120,us1120,LE1120,30,cmap="coolwarm")
plt.colorbar()
plt.show()

x1120 = pxr.x_array(rs1120,us1120)
z1120 = pxr.z_array(rs1120,us1120)

plt.figure(figsize=(20,20))
plt.contourf(x1120,z1120,np.swapaxes(LE1120,0,1),200,vmax = 0.2, cmap="magma")
plt.plot([x/ap for x in m.DS.rbbbs],[y/ap for y in m.DS.zbbbs],"k--")
plt.xlabel('R(m)')
plt.ylabel('Z(m)')
plt.axes().set_aspect("equal")
plt.colorbar()
plt.show()
# Out:
# /usr/projects/hpcsoft/toss3/common/anaconda/5.0.1-python-3.6/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## t=1160

# %%
le1160_path = "/lustre/scratch4/turquoise/giannis_kx/pixie3d/iter/int_kink/11/ftle-chipar/t-1160/"

A1160 = np.load(le1160_path+"raw_t-1160.sav.npz_giri_2.py.npz")

rs1160 = A1160['rr']
us1160 = A1160['th']
LE1160 = A1160['Lyap_exp']

plt.figure(figsize=(8,8))
plt.contourf(rs1160,us1160,LE1160,30,cmap="coolwarm")
plt.colorbar()
plt.show()

x1160 = pxr.x_array(rs1160,us1160)
z1160 = pxr.z_array(rs1160,us1160)

plt.figure(figsize=(20,20))
plt.contourf(x1160,z1160,np.swapaxes(LE1160,0,1),200,vmax = 0.2, cmap="magma")
plt.plot([x/ap for x in m.DS.rbbbs],[y/ap for y in m.DS.zbbbs],"k--")
plt.xlabel('R(m)')
plt.ylabel('Z(m)')
plt.axes().set_aspect("equal")
plt.colorbar()
plt.show()
# Out:
# /usr/projects/hpcsoft/toss3/common/anaconda/5.0.1-python-3.6/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## Checking dx resolution

# %%
le920_e8_path = "/lustre/scratch4/turquoise/giannis_kx/pixie3d/iter/int_kink/11/ftle-chipar/t-920/10-8/"

A920_e8 = np.load(le920_e8_path+"raw_t-920-e-8.sav.npz_giri_2.py.npz")

rs920_e8 = A920_e8['rr']
us920_e8 = A920_e8['th']
LE920_e8 = A920_e8['Lyap_exp']

plt.figure(figsize=(8,8))
plt.contourf(rs920_e8,us920_e8,LE920_e8,30,cmap="coolwarm")
plt.colorbar()
plt.show()

x920_e8 = pxr.x_array(rs920_e8,us920_e8)
z920_e8 = pxr.z_array(rs920_e8,us920_e8)

plt.figure(figsize=(20,20))
plt.contourf(x920_e8,z920_e8,np.swapaxes(LE920_e8,0,1),200,vmax = 0.2, cmap="magma")
plt.plot([x/ap for x in m.DS.rbbbs],[y/ap for y in m.DS.zbbbs],"k--")
plt.xlabel('R(m)')
plt.ylabel('Z(m)')
plt.axes().set_aspect("equal")
plt.colorbar()
plt.show()
# Out:
# /usr/projects/hpcsoft/toss3/common/anaconda/5.0.1-python-3.6/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
le920_e9_path = "/lustre/scratch4/turquoise/giannis_kx/pixie3d/iter/int_kink/11/ftle-chipar/t-920/10-9/"

A920_e9 = np.load(le920_e9_path+"raw_t-920-e-9.sav.npz_giri_2.py.npz")

rs920_e9 = A920_e9['rr']
us920_e9 = A920_e9['th']
LE920_e9 = A920_e9['Lyap_exp']

plt.figure(figsize=(8,8))
plt.contourf(rs920_e9,us920_e9,LE920_e9,30,cmap="coolwarm")
plt.colorbar()
plt.show()

x920_e9 = pxr.x_array(rs920_e9,us920_e9)
z920_e9 = pxr.z_array(rs920_e9,us920_e9)

plt.figure(figsize=(20,20))
plt.contourf(x920_e9,z920_e9,np.swapaxes(LE920_e9,0,1),200,vmax = 0.2, cmap="magma")
plt.plot([x/ap for x in m.DS.rbbbs],[y/ap for y in m.DS.zbbbs],"k--")
plt.xlabel('R(m)')
plt.ylabel('Z(m)')
plt.axes().set_aspect("equal")
plt.colorbar()
plt.show()
# Out:
# /usr/projects/hpcsoft/toss3/common/anaconda/5.0.1-python-3.6/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
le920_e10_path = "/lustre/scratch4/turquoise/giannis_kx/pixie3d/iter/int_kink/11/ftle-chipar/t-920/10-10/"

A920_e10 = np.load(le920_e10_path+"raw_t-920-e-10.sav.npz_giri_2.py.npz")

rs920_e10 = A920_e10['rr']
us920_e10 = A920_e10['th']
LE920_e10 = A920_e10['Lyap_exp']

plt.figure(figsize=(8,8))
plt.contourf(rs920_e10,us920_e10,LE920_e10,30,cmap="coolwarm")
plt.colorbar()
plt.show()

x920_e10 = pxr.x_array(rs920_e10,us920_e10)
z920_e10 = pxr.z_array(rs920_e10,us920_e10)

plt.figure(figsize=(20,20))
plt.contourf(x920_e10,z920_e10,np.swapaxes(LE920_e10,0,1),200,vmax=0.2,cmap="magma")
plt.plot([x/ap for x in m.DS.rbbbs],[y/ap for y in m.DS.zbbbs],"k--")
plt.xlabel('R(m)')
plt.ylabel('Z(m)')
plt.axes().set_aspect("equal")
plt.colorbar()
plt.show()
# Out:
# /usr/projects/hpcsoft/toss3/common/anaconda/5.0.1-python-3.6/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
