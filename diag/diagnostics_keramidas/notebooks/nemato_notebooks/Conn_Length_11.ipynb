# %%
import numpy as np
import matplotlib.pyplot as plt
import connection_length as cnc
from importlib import reload

# %%
reload(cnc)
# Out:
# <module 'connection_length' from '/turquoise/users/giannis_kx/python_pixie/connection_length.py'>

# %% [markdown]
# ## Storing Coordinate arrays

# %%
cnc.store_coordinate_arrays("/net/scratch4/giannis_kx/pixie3d/iter/int_kink/11/11_visc.scratch/")

# %% [markdown]
# ## Read Coordinates

# %%
reload(cnc)
# Out:
# <module 'connection_length' from '/turquoise/users/giannis_kx/python_pixie/connection_length.py'>

# %%
X,Z,Psi = cnc.read_coordinates("/net/scratch4/giannis_kx/pixie3d/iter/int_kink/11/11_visc.scratch/")

# %% [markdown]
# ##  Read Connection Lengths

# %%
reload(cnc)
# Out:
# <module 'connection_length' from '/turquoise/users/giannis_kx/python_pixie/connection_length.py'>

# %%
xs,zs,conn = cnc.read_connection_lengths("/net/scratch4/giannis_kx/pixie3d/iter/int_kink/11/11_visc.scratch/",32)

# %% [markdown]
# ## Plotting

# %%
plt.figure(figsize=(20,20))
cs = plt.tricontourf(xs,zs,conn,levels=np.linspace(0,2000,20),cmap='plasma_r',extend='both')
#cs.cmap.set_over('k')
#cs.cmap.set_under('y')
plt.xlabel('R (m)')
plt.ylabel('Z (m)')
plt.colorbar()
plt.contour(X[:,:,0],Z[:,:,0],Psi[:,:,0],60, colors='green')
#plt.xlim(1.75,4.0)
plt.show()
