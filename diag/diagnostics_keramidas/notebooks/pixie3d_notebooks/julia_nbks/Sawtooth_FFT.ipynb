# %%
using Interpolations
using NPZ
using Plots
using PyPlot 
import PyPlot
using LaTeXStrings
using Statistics
using PyCall
using FFTW

# %%
include("fftUtils.jl");
using .fftUtils

# %%
filepath = "/net/scratch3/giannis_kx/pixie3d/tests/bonfiglio_div_tok/sawtooth2.scratch/";

# %%
A = npzread(filepath * "b_hat_rho_mpi.npy");

# %%
q = npzread(filepath * "q_mpi.npy");

# %%
size(q)
# Out:
# (101, 106)

# %%
time = LinRange(524,630,106);

# %%
psi = LinRange(0,1,101);

# %%
bhat = fft(A,[2,3]);

# %%
Plots.plot(time,q[1,:])

# %%
Plots.plot(time,imag(bhat[6,2,2,:]))

# %%
Plots.plot(psi,imag(bhat[:,2,end,100]))
Plots.plot!(psi,imag(bhat[:,end-1,2,101]))
Plots.plot!(psi,imag(bhat[:,end-2,2,101]))
Plots.plot!(psi,imag(bhat[:,end-3,2,101]))
