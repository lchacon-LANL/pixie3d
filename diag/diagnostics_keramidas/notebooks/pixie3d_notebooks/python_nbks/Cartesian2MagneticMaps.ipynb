# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pylab as py
import numpy as np
from imp import reload
import pixie_read_st as pxr

# %%
plt.style.use('ggplot')
plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.labelweight'] = 'heavy'
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['figure.titlesize'] = 12
plt.rcParams['text.usetex']=True

# %%
filepath = "/net/scratch3/giannis_kx/pixie3d/iter/iter3d/db_new/dt.scratch/"

# %%
pxr.pixieload(filepath + "pixie3d.h5")
# Out:
# timesteps= 204
# Dictionary of terms:
# Variables: ['Car_variables', 'Cnv_variables', 'Cov_variables', 'Diagnostics', 'Perturbations', 'cells', 'nodes']
# Cartesian: ['Bx', 'By', 'Bz', 'Jx', 'Jy', 'Jz', 'Prs', 'Ve_1', 'Ve_2', 'Ve_3', 'Vx', 'Vy', 'Vz', 'rho']
# Contravariant: ['B^1', 'B^2', 'B^3', 'J*P^2', 'J.(pi+pe)', 'J.Rho', 'J^1', 'J^2', 'J^3', 'P^1', 'P^3']
# Covariant: ['B_1', 'B_2', 'B_3', 'J_1', 'J_2', 'J_3', 'T=Te+Ti', 'V_1', 'V_2', 'V_3', 'rho']
# Diagnostic: ['E_1', 'E_2', 'E_3', 'Int. heat src', 'Poloidal flux', 'Ti+Te', 'chi par', 'chi perp', 'diff', 'eta', 'lambda', 'local div(B)', 'local div(J)', 'local div(V)', 'nu', 'q factor']
# Perturbations: ['B^1_pert', 'B^2_pert', 'B^3_pert', 'P^1_pert', 'P^2_pert', 'P^3_pert', 'Prs_pert', 'Rho_pert']
# Cell: ['X', 'Y', 'Z']
# Node: ['X', 'Y', 'Z']

# %%
psi_init = pxr.load_array(3,4,0,5)

# %%
X = np.load(filepath + "X.npy")
Z = np.load(filepath + "Z.npy")

# %%
uf = np.linspace(0,2*np.pi,num=65)

# %%
plt.figure(figsize=(20,20))
plt.title("Mapped points to flux surface, t=0")
plt.contour(pxr.X[:,:,0],pxr.Z[:,:,0],psi_init[:,:,0,0],50)
plt.plot(X[81,:,0,0],Z[81,:,0,0],"*")
plt.xlabel("R(m)")
plt.ylabel("Z(m)")
plt.show()

# %%
psi_mid = pxr.load_array(3,4,140,145)

# %%
plt.figure(figsize=(20,20))
plt.title("Mapped points to flux surface, t=140")
plt.contour(pxr.X[:,:,0],pxr.Z[:,:,0],psi_mid[:,:,0,0],100)
plt.plot(X[81,:,0,140],Z[81,:,0,140],"*")
plt.xlabel("R(m)")
plt.ylabel("Z(m)")
plt.show()

# %%
plt.title("Wandering of magnetic axis")
plt.plot(X[0,0,0,:],Z[0,0,0,:],"*")
plt.xlabel("R(m)")
plt.ylabel("Z(m)")
plt.show()

# %%
plt.title("Wandering of random point")
plt.plot(X[33,0,0,:],Z[33,0,0,:],"*")
plt.xlabel("R(m)")
plt.ylabel("Z(m)")
plt.show()
