# %%
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload

# %% [markdown]
# ## Test with analytical Cartesian metric

# %%
le_path = "/net/scratch3/giannis_kx/FTLE/test/"

# %%
A = np.load(le_path+"raw2_prova.sav.npz_giri_2.py.npz")

# %%
rs = A['rr']
us = A['th']
LE = A['Lyap_exp']

# %%
plt.contourf(rs,us,LE)
plt.show()

# %% [markdown]
# ## Test with numerical Cartesian metric

# %%
le_path2 = "/net/scratch3/giannis_kx/FTLE/test_cartesian/"

# %%
B = np.load(le_path2+"raw2_prova.sav.npz_giri_2.py.npz")

# %%
rs2 = B['rr']
us2 = B['th']
LE2 = B['Lyap_exp']

# %%
plt.contourf(rs2,us2,LE2)
plt.show()

# %% [markdown]
# ## Test with analytical cylindrical metric

# %%
le_path3 = "/net/scratch3/giannis_kx/FTLE/cyl_analytic/"

# %%
C = np.load(le_path3+"raw2_prova.sav.npz_giri_2.py.npz")

# %%
rs3 = C['rr']
us3 = C['th']
LE3 = C['Lyap_exp']

# %%
plt.contourf(rs3,us3,LE3)
plt.show()

# %% [markdown]
# ## Test with numerical cylindrical metric

# %%
le_path4 = "/net/scratch3/giannis_kx/FTLE/cyl_numeric/"

# %%
D = np.load(le_path4+"raw2_prova.sav.npz_giri_2.py.npz")

# %%
rs4 = D['rr']
us4 = D['th']
LE4 = D['Lyap_exp']

# %%
plt.contourf(rs4,us4,LE4)
plt.show()

# %% [markdown]
# ## Difference between numerical/analytical in Cylindrical case

# %%
diff_cyl = LE3-LE4

# %%
plt.contourf(rs4,us4,diff_cyl)
plt.colorbar()
plt.show()

# %% [markdown]
# ## Difference between Cartesian and Cylindrical cases

# %%
diff_cyl_car = LE2-LE3

# %%
plt.contourf(rs4,us4,diff_cyl_car)
plt.colorbar()
plt.show()

# %% [markdown]
# ## Difference between numerical/analytical in Cartesian case

# %%
diff_car = LE-LE2

# %%
plt.contourf(rs2,us2,diff_car)
plt.colorbar()
plt.show()
